# %%
# deploying pricerservice file to Modal env which loads and runs the LLAMA model and QLORA trained model to estimate the price

# !modal deploy -m pricerservice

# %%
# Testing specialist agent which is deployed as part of above step
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")

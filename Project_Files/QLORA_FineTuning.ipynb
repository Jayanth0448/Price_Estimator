# %% [markdown]
# **Please access the below google colab link as I needed to A100 GPU for training the model to find the code for QLORA Finetuning**\
#
# [Colab Notebook](https://colab.research.google.com/drive/1Cgz0sBSwfaiBxz47GR2lbRuo_KDt-H_m#scrollTo=smeCmfoOi8KP)
#
#
# **After Finetuning the model below are the observation**
# 1. Significant Accuracy Improvement
#
# Finetuned model achieved 62.8% accuracy, more than 2× better than the base LLaMA model (28%), demonstrating strong task-specific learning.
#
# 2. Stable and Healthy Training Dynamics
#
# Training loss decreased smoothly (1.95 → 1.70), with stable gradient norms and a clean learning-rate warm-up + decay schedule, indicating no training instability.
#
# 3. Efficient LoRA Finetuning
#
# LoRA configuration (rank, alpha, dropout) worked effectively, enabling fast and stable training without overfitting—even with only ~0.6 epochs completed.
#
# 4. Proven End-to-End Pipeline
#
# Dataset quality, preprocessing, LoRA setup, and training procedure all aligned well, resulting in a reliable, high-performing finetuned model suitable for real use.
